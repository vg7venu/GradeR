# %%
# Importing Required packages and Modules
import pandas as pd

# Importing Data Set 
data = pd.read_excel(r"D:\Task\GradeR\cse.xlsx")
data
# Out:
#            Htno   Subcode                                   Subname Grade  \
# 0    166M1A0501  R1641051  CRYPTOGRAPHY AND NETWORK SECURITY  (COMM     F
# 1    166M1A0501  R1641052   SOFTWARE ARCHITECTURE & DEISGN PATTERNS     D
# 2    166M1A0501  R1641053                          WEB TECHNOLOGIES     F
# 3    166M1A0501  R1641054  MANAGERIAL ECONOMICS AND FINANCIAL ANALY     F
# 4    166M1A0501  R1641057   SOFTWARE ARCHITECURES & DESIGN PATTERNS     A
# 5    166M1A0501  R1641058                      WEB TECHNOLOGIES LAB     O
# 6    166M1A0501  R164105A       BIG DATA ANALYSIS(COMMON TO CSE,IT)     F
# 7    166M1A0501  R164105D         CLOUD COMPUTING(COMMON TO CSE,IT)     F
# 8    166M1A0502  R1641051  CRYPTOGRAPHY AND NETWORK SECURITY  (COMM     D
# 9    166M1A0502  R1641052   SOFTWARE ARCHITECTURE & DEISGN PATTERNS     C
# 10   166M1A0502  R1641053                          WEB TECHNOLOGIES     D
# 11   166M1A0502  R1641054  MANAGERIAL ECONOMICS AND FINANCIAL ANALY     C
# 12   166M1A0502  R1641057   SOFTWARE ARCHITECURES & DESIGN PATTERNS     S
# 13   166M1A0502  R1641058                      WEB TECHNOLOGIES LAB     O
# 14   166M1A0502  R164105A       BIG DATA ANALYSIS(COMMON TO CSE,IT)     C
# 15   166M1A0502  R164105D         CLOUD COMPUTING(COMMON TO CSE,IT)     B
# 16   166M1A0503  R1641051  CRYPTOGRAPHY AND NETWORK SECURITY  (COMM     B
# 17   166M1A0503  R1641052   SOFTWARE ARCHITECTURE & DEISGN PATTERNS     C
# 18   166M1A0503  R1641053                          WEB TECHNOLOGIES     C
# 19   166M1A0503  R1641054  MANAGERIAL ECONOMICS AND FINANCIAL ANALY     A
# 20   166M1A0503  R1641057   SOFTWARE ARCHITECURES & DESIGN PATTERNS     S
# 21   166M1A0503  R1641058                      WEB TECHNOLOGIES LAB     O
# 22   166M1A0503  R164105A       BIG DATA ANALYSIS(COMMON TO CSE,IT)     B
# 23   166M1A0503  R164105D         CLOUD COMPUTING(COMMON TO CSE,IT)     C
# 24   166M1A0504  R1641051  CRYPTOGRAPHY AND NETWORK SECURITY  (COMM     C
# 25   166M1A0504  R1641052   SOFTWARE ARCHITECTURE & DEISGN PATTERNS     C
# 26   166M1A0504  R1641053                          WEB TECHNOLOGIES     C
# 27   166M1A0504  R1641054  MANAGERIAL ECONOMICS AND FINANCIAL ANALY     C
# 28   166M1A0504  R1641057   SOFTWARE ARCHITECURES & DESIGN PATTERNS     S
# 29   166M1A0504  R1641058                      WEB TECHNOLOGIES LAB     O
# ..          ...       ...                                       ...   ...
# 442  166M1A0557  R1641053                          WEB TECHNOLOGIES     D
# 443  166M1A0557  R1641054  MANAGERIAL ECONOMICS AND FINANCIAL ANALY     D
# 444  166M1A0557  R1641057   SOFTWARE ARCHITECURES & DESIGN PATTERNS     S
# 445  166M1A0557  R1641058                      WEB TECHNOLOGIES LAB     O
# 446  166M1A0557  R164105A       BIG DATA ANALYSIS(COMMON TO CSE,IT)     F
# 447  166M1A0557  R164105D         CLOUD COMPUTING(COMMON TO CSE,IT)     D
# 448  166M1A0558  R1641051  CRYPTOGRAPHY AND NETWORK SECURITY  (COMM     F
# 449  166M1A0558  R1641052   SOFTWARE ARCHITECTURE & DEISGN PATTERNS     C
# 450  166M1A0558  R1641053                          WEB TECHNOLOGIES     C
# 451  166M1A0558  R1641054  MANAGERIAL ECONOMICS AND FINANCIAL ANALY     D
# 452  166M1A0558  R1641057   SOFTWARE ARCHITECURES & DESIGN PATTERNS     B
# 453  166M1A0558  R1641058                      WEB TECHNOLOGIES LAB     S
# 454  166M1A0558  R164105A       BIG DATA ANALYSIS(COMMON TO CSE,IT)     D
# 455  166M1A0558  R164105D         CLOUD COMPUTING(COMMON TO CSE,IT)     F
# 456  166M1A0559  R1641051  CRYPTOGRAPHY AND NETWORK SECURITY  (COMM     B
# 457  166M1A0559  R1641052   SOFTWARE ARCHITECTURE & DEISGN PATTERNS     A
# 458  166M1A0559  R1641053                          WEB TECHNOLOGIES     B
# 459  166M1A0559  R1641054  MANAGERIAL ECONOMICS AND FINANCIAL ANALY     B
# 460  166M1A0559  R1641057   SOFTWARE ARCHITECURES & DESIGN PATTERNS     O
# 461  166M1A0559  R1641058                      WEB TECHNOLOGIES LAB     O
# 462  166M1A0559  R164105A       BIG DATA ANALYSIS(COMMON TO CSE,IT)     C
# 463  166M1A0559  R164105D         CLOUD COMPUTING(COMMON TO CSE,IT)     A
# 464  166M1A0560  R1641051  CRYPTOGRAPHY AND NETWORK SECURITY  (COMM     B
# 465  166M1A0560  R1641052   SOFTWARE ARCHITECTURE & DEISGN PATTERNS     D
# 466  166M1A0560  R1641053                          WEB TECHNOLOGIES     D
# 467  166M1A0560  R1641054  MANAGERIAL ECONOMICS AND FINANCIAL ANALY     D
# 468  166M1A0560  R1641057   SOFTWARE ARCHITECURES & DESIGN PATTERNS     S
# 469  166M1A0560  R1641058                      WEB TECHNOLOGIES LAB     O
# 470  166M1A0560  R164105A       BIG DATA ANALYSIS(COMMON TO CSE,IT)     C
# 471  166M1A0560  R164105D         CLOUD COMPUTING(COMMON TO CSE,IT)     D
#
#      Credits
# 0          0
# 1          3
# 2          0
# 3          0
# 4          2
# 5          2
# 6          0
# 7          0
# 8          3
# 9          3
# 10         3
# 11         3
# 12         2
# 13         2
# 14         3
# 15         3
# 16         3
# 17         3
# 18         3
# 19         3
# 20         2
# 21         2
# 22         3
# 23         3
# 24         3
# 25         3
# 26         3
# 27         3
# 28         2
# 29         2
# ..       ...
# 442        3
# 443        3
# 444        2
# 445        2
# 446        0
# 447        3
# 448        0
# 449        3
# 450        3
# 451        3
# 452        2
# 453        2
# 454        3
# 455        0
# 456        3
# 457        3
# 458        3
# 459        3
# 460        2
# 461        2
# 462        3
# 463        3
# 464        3
# 465        3
# 466        3
# 467        3
# 468        2
# 469        2
# 470        3
# 471        3
#
# [472 rows x 5 columns]

# %%
# Extracting Subject : Code,Names and Student's ID 
subjectCodes = data['Subcode'].unique()
subjectNames = data['Subname'].unique()
studentIds = data.Htno.unique()
credits = data.Credits
creditsMax = []
for subcredit in range(0,len(credits),len(subjectCodes)):
        creditsMax.append(sum(credits[subcredit:subcredit+len(subjectCodes)]))
creditsMax = max(creditsMax)
creditsMax
# Out:
# 22

# %%
# Creating the Header for the Main DataFrame
def createColumns():
    columnsList = []
    columnsList.append('ID')
    for code in subjectCodes:
        columnsList.append(code)
    columnsList.append('GPA')
    return columnsList

gpaDF = pd.DataFrame(columns=createColumns())

# %%
# Used to Calculate the GPA of the Each student 
def calcGpa(subjectGrades,subjectCredits):
    total = 0
    for i in range(0,len(subjectGrades)):
        total = total + (subjectGrades[i]*subjectCredits[i])
    return total/creditsMax

# Creates and Appends the Rows of Each student containing ID..SubjectGrades...GPA respectively
def createStudentRow(ide,subjectGrades,subjectCredits):
    row = []
    row.append(ide)
    for grade in subjectGrades:
        row.append(grade)
    row.append(calcGpa(subjectGrades,subjectCredits))
    stu_row = pd.DataFrame([row],columns=createColumns())
    return stu_row

# Main GPADataFrame
for ide in studentIds:
    subjectGrades = data.loc[data['Htno']== ide].Grade.tolist()
    subjectCredits = data.loc[data['Htno']== ide].Credits.tolist()
    for n, i in enumerate(subjectGrades):
        if i == 'O':subjectGrades[n] = 10
        if i == 'S':subjectGrades[n] = 9
        if i == 'A':subjectGrades[n] = 8
        if i == 'B':subjectGrades[n] = 7
        if i == 'C':subjectGrades[n] = 6
        if i == 'D':subjectGrades[n] = 5
        if i == 'F':subjectGrades[n] = 0
        if i == 'ABSENT':subjectGrades[n] = 0
    stu_row = createStudentRow(ide,subjectGrades,subjectCredits)
    gpaDF = gpaDF.append(stu_row,ignore_index=True)
gpaDF
# Out:
#             ID R1641051 R1641052 R1641053 R1641054 R1641057 R1641058 R164105A  \
# 0   166M1A0501        0        5        0        0        8       10        0
# 1   166M1A0502        5        6        5        6        9       10        6
# 2   166M1A0503        7        6        6        8        9       10        7
# 3   166M1A0504        6        6        6        6        9       10        6
# 4   166M1A0505        0        7        7        7        9        9        5
# 5   166M1A0506        6        6        7        5        9       10        6
# 6   166M1A0507        7        5        7        7        9       10        5
# 7   166M1A0508        5        5        0        5        8       10        6
# 8   166M1A0509        0        6        0        6        8       10        0
# 9   166M1A0510        5        6        7        6        9       10        5
# 10  166M1A0511        6        0        5        6        7       10        0
# 11  166M1A0512        6        6        8        0        8       10        6
# 12  166M1A0513        5        7        6        6        8       10        6
# 13  166M1A0514        6        6        6        7        8       10        6
# 14  166M1A0515        8        7        5        8        9       10        7
# 15  166M1A0516        6        7        7        6        9       10        5
# 16  166M1A0517        5        6        5        5        8        9        5
# 17  166M1A0518        5        5        5        5        7        9        5
# 18  166M1A0519        9        7        7        8       10       10        7
# 19  166M1A0520        6        6        6        5        9       10        5
# 20  166M1A0521        5        8        6        0        8       10        6
# 21  166M1A0522        6        6        5        6        9       10        7
# 22  166M1A0523        7        6        6        7       10       10        6
# 23  166M1A0524        7        8        8        6       10       10        7
# 24  166M1A0525        6        8        7        6        9       10        6
# 25  166M1A0526        6        7        6        6        9       10        7
# 26  166M1A0527        8        0        5        6        9       10        6
# 27  166M1A0528        6        6        5        5        8       10        0
# 28  166M1A0529        0        6        5        0        8       10        0
# 29  166M1A0530        5        6        5        6        8        9        0
# 30  166M1A0531        8        0        5        6        9       10        7
# 31  166M1A0532        6        7        0        5        9       10        6
# 32  166M1A0533        0        7        5        5        8       10        0
# 33  166M1A0534        5        6        5        6        9       10        0
# 34  166M1A0535        9        6        6        7        9       10        7
# 35  166M1A0536        6        5        0        5        9       10        5
# 36  166M1A0537        5        8        6        6       10       10        6
# 37  166M1A0538        7        7        6        7       10       10        6
# 38  166M1A0539        5        0        0        5        9       10        0
# 39  166M1A0540        6        8        6        5        9       10        6
# 40  166M1A0541        0        7        5        5        9       10        5
# 41  166M1A0542        8        6        7        7        9       10        6
# 42  166M1A0543        8        7        6        7       10       10        6
# 43  166M1A0545        8        8        7        6        9       10        7
# 44  166M1A0546        5        6        5        5        9       10        5
# 45  166M1A0547        7        7        6        7       10       10        7
# 46  166M1A0548        7        6        7        6       10       10        5
# 47  166M1A0549        7        9        7        6       10       10        7
# 48  166M1A0550        6        8        7        7        9       10        5
# 49  166M1A0551        6        6        5        6        9       10        5
# 50  166M1A0552        7        6        6        6        9       10        6
# 51  166M1A0553        5        6        0        5        8       10        5
# 52  166M1A0554        5        5        5        0        9       10        0
# 53  166M1A0555        6        6        5        6        9       10        5
# 54  166M1A0556        8        6        6        6        9       10        6
# 55  166M1A0557        5        6        5        5        9       10        0
# 56  166M1A0558        0        6        6        5        7        9        5
# 57  166M1A0559        7        8        7        7       10       10        6
# 58  166M1A0560        7        5        5        5        9       10        6
#
#    R164105D       GPA
# 0         0  2.318182
# 1         7  6.500000
# 2         6  7.181818
# 3         6  6.636364
# 4         5  5.863636
# 5         8  6.909091
# 6         6  6.772727
# 7         5  5.181818
# 8         5  3.954545
# 9         6  6.500000
# 10        0  3.863636
# 11        5  5.863636
# 12        6  6.545455
# 13        7  6.818182
# 14        6  7.318182
# 15        6  6.772727
# 16        0  5.090909
# 17        6  5.681818
# 18        7  7.954545
# 19        6  6.363636
# 20        5  5.727273
# 21        8  6.909091
# 22        6  7.000000
# 23        7  7.681818
# 24        6  7.045455
# 25        8  7.181818
# 26        6  5.954545
# 27        5  5.318182
# 28        0  3.136364
# 29        6  5.363636
# 30        5  5.954545
# 31        5  5.681818
# 32        0  3.954545
# 33        6  5.545455
# 34        6  7.318182
# 35        5  5.272727
# 36        0  6.045455
# 37        7  7.272727
# 38        5  3.772727
# 39        5  6.636364
# 40        5  5.409091
# 41        7  7.318182
# 42        7  7.409091
# 43        7  7.590909
# 44        0  5.272727
# 45        8  7.545455
# 46        6  6.863636
# 47        8  7.818182
# 48        5  6.909091
# 49        8  6.636364
# 50        6  6.772727
# 51        0  4.500000
# 52        0  3.772727
# 53        7  6.500000
# 54        6  6.909091
# 55        5  5.272727
# 56        0  4.454545
# 57        8  7.681818
# 58        5  6.227273

# %%
# Single Student GPA Query

studentInp = input("Enter your Rollnumber:").upper()
print(f'The GPA of {studentInp}:'+gpaDF.loc[gpaDF['ID']==studentInp].GPA.to_string(index=False))
# Out:
# Enter your Rollnumber:166m1a0522
# The GPA of 166M1A0522: 6.909091

# %%
# Subject Wise Total

subjectName = input("Enter the Subject Name:").upper()
print(subjectName)
topperCount = int(input("Enter the no.of topper count:"))
subjectTopper = sorted(gpaDF[subjectName].unique(),reverse=True)[:topperCount]
subjectTopper
for rank,top in enumerate(subjectTopper):
    print(f'Rank {rank+1}\n'+gpaDF.loc[gpaDF[subjectName]==top].ID.to_string(index=False))
# Out:
# Enter the Subject Name:r1641052
# R1641052
# Enter the no.of topper count:3
# Rank 1
#  166M1A0549
# Rank 2
#  166M1A0521
#  166M1A0524
#  166M1A0525
#  166M1A0537
#  166M1A0540
#  166M1A0545
#  166M1A0550
#  166M1A0559
# Rank 3
#  166M1A0505
#  166M1A0513
#  166M1A0515
#  166M1A0516
#  166M1A0519
#  166M1A0526
#  166M1A0532
#  166M1A0533
#  166M1A0538
#  166M1A0541
#  166M1A0543
#  166M1A0547

# %%
#Top count GPA students

gpatopCount = int(input("Enter No.of Toppers count:"))
gpaTop = sorted(gpaDF['GPA'].unique(),reverse=True)[:gpatopCount]

for gtop in gpaTop:   
    print(f'{gpaDF.loc[gpaDF["GPA"]==gtop].ID.to_string(index=False)}:{gtop}')
    print()
# Out:
# Enter No.of Toppers count:5
#  166M1A0519:7.954545454545454
#
#  166M1A0549:7.818181818181818
#
#  166M1A0524
#  166M1A0559:7.681818181818182
#
#  166M1A0545:7.590909090909091
#
#  166M1A0547:7.545454545454546

# %%
# Saving GPA results into a local CSV file
gpaDF.to_csv('GPAoutput.csv')
